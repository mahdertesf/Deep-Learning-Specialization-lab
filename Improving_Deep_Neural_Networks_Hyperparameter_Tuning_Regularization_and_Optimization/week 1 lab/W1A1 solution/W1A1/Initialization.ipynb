# %% [markdown]
# # Initialization
#
# Welcome to the first assignment of Improving Deep Neural Networks!
#
# Training your neural network requires specifying an initial value of the weights. A well-chosen initialization method helps the learning process.
#
# If you completed the previous course of this specialization, you probably followed the instructions for weight initialization, and seen that it's worked pretty well so far. But how do you choose the initialization for a new neural network? In this notebook, you'll try out a few different initializations, including random, zeros, and He initialization, and see how each leads to different results.
#
# A well-chosen initialization can:
# - Speed up the convergence of gradient descent
# - Increase the odds of gradient descent converging to a lower training (and generalization) error
#
# Let's get started!
#
# ## Important Note on Submission to the AutoGrader
#
# Before submitting your assignment to the AutoGrader, please make sure you are not doing the following:
#
# 1. You have not added any _extra_ `print` statement(s) in the assignment.
# 2. You have not added any _extra_ code cell(s) in the assignment.
# 3. You have not changed any of the function parameters.
# 4. You are not using any global variables inside your graded exercises. Unless specifically instructed to do so, please refrain from it and use the local variables instead.
# 5. You are not changing the assignment code where it is not required, like creating _extra_ variables.
#
# If you do any of the following, you will get something like, `Grader Error: Grader feedback not found` (or similarly unexpected) error upon submitting your assignment. Before asking for help/debugging the errors in your assignment, check for these first. If this is the case, and you don't remember the changes you have made, you can get a fresh copy of the assignment by following these [instructions](https://www.coursera.org/learn/deep-neural-network/supplement/QWEnZ/h-ow-to-refresh-your-workspace).

# %% [markdown]
# ## Table of Contents
# - [1 - Packages](#1)
# - [2 - Loading the Dataset](#2)
# - [3 - Neural Network Model](#3)
# - [4 - Zero Initialization](#4)
#     - [Exercise 1 - initialize_parameters_zeros](#ex-1)
# - [5 - Random Initialization](#5)
#     - [Exercise 2 - initialize_parameters_random](#ex-2)
# - [6 - He Initialization](#6)
#     - [Exercise 3 - initialize_parameters_he](#ex-3)
# - [7 - Conclusions](#7)

# %% [markdown]
# <a name='1'></a>
# ## 1 - Packages

# %%
### v1.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import sklearn.datasets
from public_tests import *
from init_utils import sigmoid, relu, compute_loss, forward_propagation, backward_propagation
from init_utils import update_parameters, predict, load_dataset, plot_decision_boundary, predict_dec

# %matplotlib inline
plt.rcParams['figure.figsize'] = (7.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

# load image dataset: blue/red dots in circles
# train_X, train_Y, test_X, test_Y = load_dataset()

# %% [markdown]
# <a name='2'></a>
# ## 2 - Loading the Dataset

# %%
train_X, train_Y, test_X, test_Y = load_dataset()

# %% [markdown]
# For this classifier, you want to separate the blue dots from the red dots.

# %% [markdown]
# <a name='3'></a>
# ## 3 - Neural Network Model

# %% [markdown]
# You'll use a 3-layer neural network (already implemented for you). These are the initialization methods you'll experiment with:
# - *Zeros initialization* --  setting `initialization = "zeros"` in the input argument.
# - *Random initialization* -- setting `initialization = "random"` in the input argument. This initializes the weights to large random values.
# - *He initialization* -- setting `initialization = "he"` in the input argument. This initializes the weights to random values scaled according to a paper by He et al., 2015.
#
# **Instructions**: Instructions: Read over the code below, and run it. In the next part, you'll implement the three initialization methods that this `model()` calls.

# %%
def model(X, Y, learning_rate = 0.01, num_iterations = 300000, print_cost = True, initialization = "he"):
    """
    Implements a three-layer neural network: LINEAR->RELU->LINEAR->RELU->LINEAR->SIGMOID.
    
    Arguments:
    X -- input data, of shape (2, number of examples)
    Y -- true "label" vector (containing 0 for red dots; 1 for blue dots), of shape (1, number of examples)
    learning_rate -- learning rate for gradient descent 
    num_iterations -- number of iterations to run gradient descent
    print_cost -- if True, print the cost every 1000 iterations
    initialization -- flag to choose which initialization to use ("zeros","random" or "he")
    
    Returns:
    parameters -- parameters learnt by the model
    """
        
    grads = {}
    costs = [] # to keep track of the loss
    m = X.shape[1] # number of examples
    layers_dims = [X.shape[0], 10, 5, 1]
    
    # Initialize parameters dictionary.
    if initialization == "zeros":
        parameters = initialize_parameters_zeros(layers_dims)
    elif initialization == "random":
        parameters = initialize_parameters_random(layers_dims)
    elif initialization == "he":
        parameters = initialize_parameters_he(layers_dims)

    # Loop (gradient descent)

    for i in range(num_iterations):

        # Forward propagation: LINEAR -> RELU -> LINEAR -> RELU -> LINEAR -> SIGMOID.
        a3, cache = forward_propagation(X, parameters)
        
        # Loss
        cost = compute_loss(a3, Y)

        # Backward propagation.
        grads = backward_propagation(X, Y, cache)
        
        # Update parameters.
        parameters = update_parameters(parameters, grads, learning_rate)
        
        # Print the loss every 1000 iterations
        if print_cost and i % 1000 == 0:
            print("Cost after iteration {}: {}".format(i, cost))
            costs.append(cost)
            
    # plot the loss
    plt.plot(costs)
    plt.ylabel('cost')
    plt.xlabel('iterations (per hundreds)')
    plt.title("Learning rate =" + str(learning_rate))
    plt.show()
    
    return parameters

# %% [markdown]
# <a name='4'></a>
# ## 4 - Zero Initialization
#
# There are two types of parameters to initialize in a neural network:
# - the weight matrices $(W^{[1]}, W^{[2]}, W^{[3]}, ..., W^{[L-1]}, W^{[L]})$
# - the bias vectors $(b^{[1]}, b^{[2]}, b^{[3]}, ..., b^{[L-1]}, b^{[L]})$
#
# <a name='ex-1'></a>
# ### Exercise 1 - initialize_parameters_zeros
#
# Implement the following function to initialize all parameters to zeros. You'll see later that this does not work well since it fails to "break symmetry," but try it anyway and see what happens. Use `np.zeros((..,..))` with the correct shapes.

# %%
# GRADED FUNCTION: initialize_parameters_zeros 

def initialize_parameters_zeros(layers_dims):
    """
    Arguments:
    layer_dims -- python array (list) containing the size of each layer.
    
    Returns:
    parameters -- python dictionary containing your parameters "W1", "b1", ..., "WL", "bL":
                    W1 -- weight matrix of shape (layers_dims[1], layers_dims[0])
                    b1 -- bias vector of shape (layers_dims[1], 1)
                    ...
                    WL -- weight matrix of shape (layers_dims[L], layers_dims[L-1])
                    bL -- bias vector of shape (layers_dims[L], 1)
    """
    
    parameters = {}
    L = len(layers_dims)            # number of layers in the network
    
    for l in range(1, L):
        #(≈ 2 lines of code)
        # parameters['W' + str(l)] = 
        # parameters['b' + str(l)] = 
        # YOUR CODE STARTS HERE
        parameters["W"+str(l)]=np.zeros((layers_dims[l],layers_dims[l-1]))
        parameters["b"+str(l)]=np.zeros((layers_dims[l],1))
        
        
        # YOUR CODE ENDS HERE
    return parameters

# %%
parameters = initialize_parameters_zeros([3, 2, 1])
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
initialize_parameters_zeros_test(initialize_parameters_zeros)
# Out:
# W1 = [[0. 0. 0.]
#  [0. 0. 0.]]
# b1 = [[0.]
#  [0.]]
# W2 = [[0. 0.]]
# b2 = [[0.]]
#  All tests passed.

# %% [markdown]
# Run the following code to train your model on 15,000 iterations using zeros initialization.

# %%
parameters = model(train_X, train_Y, initialization = "zeros")
print ("On the train set:")
predictions_train = predict(train_X, train_Y, parameters)
print ("On the test set:")
predictions_test = predict(test_X, test_Y, parameters)
# Out:
# Cost after iteration 0: 0.6931471805599453
# Cost after iteration 1000: 0.6931471805599453
# Cost after iteration 2000: 0.6931471805599453
# Cost after iteration 3000: 0.6931471805599453
# Cost after iteration 4000: 0.6931471805599453
# Cost after iteration 5000: 0.6931471805599453
# Cost after iteration 6000: 0.6931471805599453
# Cost after iteration 7000: 0.6931471805599453
# Cost after iteration 8000: 0.6931471805599453
# Cost after iteration 9000: 0.6931471805599453
# Cost after iteration 10000: 0.6931471805599453
# Cost after iteration 11000: 0.6931471805599453
# Cost after iteration 12000: 0.6931471805599453
# Cost after iteration 13000: 0.6931471805599453
# Cost after iteration 14000: 0.6931471805599453
# Cost after iteration 15000: 0.6931471805599453
# Cost after iteration 16000: 0.6931471805599453
# Cost after iteration 17000: 0.6931471805599453
# Cost after iteration 18000: 0.6931471805599453
# Cost after iteration 19000: 0.6931471805599453
# Cost after iteration 20000: 0.6931471805599453
# Cost after iteration 21000: 0.6931471805599453
# Cost after iteration 22000: 0.6931471805599453
# Cost after iteration 23000: 0.6931471805599453
# Cost after iteration 24000: 0.6931471805599453
# Cost after iteration 25000: 0.6931471805599453
# Cost after iteration 26000: 0.6931471805599453
# Cost after iteration 27000: 0.6931471805599453
# Cost after iteration 28000: 0.6931471805599453
# Cost after iteration 29000: 0.6931471805599453
# Cost after iteration 30000: 0.6931471805599453
# Cost after iteration 31000: 0.6931471805599453
# Cost after iteration 32000: 0.6931471805599453
# Cost after iteration 33000: 0.6931471805599453
# Cost after iteration 34000: 0.6931471805599453
# Cost after iteration 35000: 0.6931471805599453
# Cost after iteration 36000: 0.6931471805599453
# Cost after iteration 37000: 0.6931471805599453
# Cost after iteration 38000: 0.6931471805599453
# Cost after iteration 39000: 0.6931471805599453
# Cost after iteration 40000: 0.6931471805599453
# Cost after iteration 41000: 0.6931471805599453
# Cost after iteration 42000: 0.6931471805599453
# Cost after iteration 43000: 0.6931471805599453
# Cost after iteration 44000: 0.6931471805599453
# Cost after iteration 45000: 0.6931471805599453
# Cost after iteration 46000: 0.6931471805599453
# Cost after iteration 47000: 0.6931471805599453
# Cost after iteration 48000: 0.6931471805599453
# Cost after iteration 49000: 0.6931471805599453
# Cost after iteration 50000: 0.6931471805599453
# Cost after iteration 51000: 0.6931471805599453
# Cost after iteration 52000: 0.6931471805599453
# Cost after iteration 53000: 0.6931471805599453
# Cost after iteration 54000: 0.6931471805599453
# Cost after iteration 55000: 0.6931471805599453
# Cost after iteration 56000: 0.6931471805599453
# Cost after iteration 57000: 0.6931471805599453
# Cost after iteration 58000: 0.6931471805599453
# Cost after iteration 59000: 0.6931471805599453
# Cost after iteration 60000: 0.6931471805599453
# Cost after iteration 61000: 0.6931471805599453
# Cost after iteration 62000: 0.6931471805599453
# Cost after iteration 63000: 0.6931471805599453
# Cost after iteration 64000: 0.6931471805599453
# Cost after iteration 65000: 0.6931471805599453
# Cost after iteration 66000: 0.6931471805599453
# Cost after iteration 67000: 0.6931471805599453
# Cost after iteration 68000: 0.6931471805599453
# Cost after iteration 69000: 0.6931471805599453
# Cost after iteration 70000: 0.6931471805599453
# Cost after iteration 71000: 0.6931471805599453
# Cost after iteration 72000: 0.6931471805599453
# Cost after iteration 73000: 0.6931471805599453
# Cost after iteration 74000: 0.6931471805599453
# Cost after iteration 75000: 0.6931471805599453
# Cost after iteration 76000: 0.6931471805599453
# Cost after iteration 77000: 0.6931471805599453
# Cost after iteration 78000: 0.6931471805599453
# Cost after iteration 79000: 0.6931471805599453
# Cost after iteration 80000: 0.6931471805599453
# Cost after iteration 81000: 0.6931471805599453
# Cost after iteration 82000: 0.6931471805599453
# Cost after iteration 83000: 0.6931471805599453
# Cost after iteration 84000: 0.6931471805599453
# Cost after iteration 85000: 0.6931471805599453
# Cost after iteration 86000: 0.6931471805599453
# Cost after iteration 87000: 0.6931471805599453
# Cost after iteration 88000: 0.6931471805599453
# Cost after iteration 89000: 0.6931471805599453
# Cost after iteration 90000: 0.6931471805599453
# Cost after iteration 91000: 0.6931471805599453
# Cost after iteration 92000: 0.6931471805599453
# Cost after iteration 93000: 0.6931471805599453
# Cost after iteration 94000: 0.6931471805599453
# Cost after iteration 95000: 0.6931471805599453
# Cost after iteration 96000: 0.6931471805599453
# Cost after iteration 97000: 0.6931471805599453
# Cost after iteration 98000: 0.6931471805599453
# Cost after iteration 99000: 0.6931471805599453
# Cost after iteration 100000: 0.6931471805599453
# Cost after iteration 101000: 0.6931471805599453
# Cost after iteration 102000: 0.6931471805599453
# Cost after iteration 103000: 0.6931471805599453
# Cost after iteration 104000: 0.6931471805599453
# Cost after iteration 105000: 0.6931471805599453
# Cost after iteration 106000: 0.6931471805599453
# Cost after iteration 107000: 0.6931471805599453
# Cost after iteration 108000: 0.6931471805599453
# Cost after iteration 109000: 0.6931471805599453
# Cost after iteration 110000: 0.6931471805599453
# Cost after iteration 111000: 0.6931471805599453
# Cost after iteration 112000: 0.6931471805599453
# Cost after iteration 113000: 0.6931471805599453
# Cost after iteration 114000: 0.6931471805599453
# Cost after iteration 115000: 0.6931471805599453
# Cost after iteration 116000: 0.6931471805599453
# Cost after iteration 117000: 0.6931471805599453
# Cost after iteration 118000: 0.6931471805599453
# Cost after iteration 119000: 0.6931471805599453
# Cost after iteration 120000: 0.6931471805599453
# Cost after iteration 121000: 0.6931471805599453
# Cost after iteration 122000: 0.6931471805599453
# Cost after iteration 123000: 0.6931471805599453
# Cost after iteration 124000: 0.6931471805599453
# Cost after iteration 125000: 0.6931471805599453
# Cost after iteration 126000: 0.6931471805599453
# Cost after iteration 127000: 0.6931471805599453
# Cost after iteration 128000: 0.6931471805599453
# Cost after iteration 129000: 0.6931471805599453
# Cost after iteration 130000: 0.6931471805599453
# Cost after iteration 131000: 0.6931471805599453
# Cost after iteration 132000: 0.6931471805599453
# Cost after iteration 133000: 0.6931471805599453
# Cost after iteration 134000: 0.6931471805599453
# Cost after iteration 135000: 0.6931471805599453
# Cost after iteration 136000: 0.6931471805599453
# Cost after iteration 137000: 0.6931471805599453
# Cost after iteration 138000: 0.6931471805599453
# Cost after iteration 139000: 0.6931471805599453
# Cost after iteration 140000: 0.6931471805599453
# Cost after iteration 141000: 0.6931471805599453
# Cost after iteration 142000: 0.6931471805599453
# Cost after iteration 143000: 0.6931471805599453
# Cost after iteration 144000: 0.6931471805599453
# Cost after iteration 145000: 0.6931471805599453
# Cost after iteration 146000: 0.6931471805599453
# Cost after iteration 147000: 0.6931471805599453
# Cost after iteration 148000: 0.6931471805599453
# Cost after iteration 149000: 0.6931471805599453
# Cost after iteration 150000: 0.6931471805599453
# Cost after iteration 151000: 0.6931471805599453
# Cost after iteration 152000: 0.6931471805599453
# Cost after iteration 153000: 0.6931471805599453
# Cost after iteration 154000: 0.6931471805599453
# Cost after iteration 155000: 0.6931471805599453
# Cost after iteration 156000: 0.6931471805599453
# Cost after iteration 157000: 0.6931471805599453
# Cost after iteration 158000: 0.6931471805599453
# Cost after iteration 159000: 0.6931471805599453
# Cost after iteration 160000: 0.6931471805599453
# Cost after iteration 161000: 0.6931471805599453
# Cost after iteration 162000: 0.6931471805599453
# Cost after iteration 163000: 0.6931471805599453
# Cost after iteration 164000: 0.6931471805599453
# Cost after iteration 165000: 0.6931471805599453
# Cost after iteration 166000: 0.6931471805599453
# Cost after iteration 167000: 0.6931471805599453
# Cost after iteration 168000: 0.6931471805599453
# Cost after iteration 169000: 0.6931471805599453
# Cost after iteration 170000: 0.6931471805599453
# Cost after iteration 171000: 0.6931471805599453
# Cost after iteration 172000: 0.6931471805599453
# Cost after iteration 173000: 0.6931471805599453
# Cost after iteration 174000: 0.6931471805599453
# Cost after iteration 175000: 0.6931471805599453
# Cost after iteration 176000: 0.6931471805599453
# Cost after iteration 177000: 0.6931471805599453
# Cost after iteration 178000: 0.6931471805599453
# Cost after iteration 179000: 0.6931471805599453
# Cost after iteration 180000: 0.6931471805599453
# Cost after iteration 181000: 0.6931471805599453
# Cost after iteration 182000: 0.6931471805599453
# Cost after iteration 183000: 0.6931471805599453
# Cost after iteration 184000: 0.6931471805599453
# Cost after iteration 185000: 0.6931471805599453
# Cost after iteration 186000: 0.6931471805599453
# Cost after iteration 187000: 0.6931471805599453
# Cost after iteration 188000: 0.6931471805599453
# Cost after iteration 189000: 0.6931471805599453
# Cost after iteration 190000: 0.6931471805599453
# Cost after iteration 191000: 0.6931471805599453
# Cost after iteration 192000: 0.6931471805599453
# Cost after iteration 193000: 0.6931471805599453
# Cost after iteration 194000: 0.6931471805599453
# Cost after iteration 195000: 0.6931471805599453
# Cost after iteration 196000: 0.6931471805599453
# Cost after iteration 197000: 0.6931471805599453
# Cost after iteration 198000: 0.6931471805599453
# Cost after iteration 199000: 0.6931471805599453
# Cost after iteration 200000: 0.6931471805599453
# Cost after iteration 201000: 0.6931471805599453
# Cost after iteration 202000: 0.6931471805599453
# Cost after iteration 203000: 0.6931471805599453
# Cost after iteration 204000: 0.6931471805599453
# Cost after iteration 205000: 0.6931471805599453
# Cost after iteration 206000: 0.6931471805599453
# Cost after iteration 207000: 0.6931471805599453
# Cost after iteration 208000: 0.6931471805599453
# Cost after iteration 209000: 0.6931471805599453
# Cost after iteration 210000: 0.6931471805599453
# Cost after iteration 211000: 0.6931471805599453
# Cost after iteration 212000: 0.6931471805599453
# Cost after iteration 213000: 0.6931471805599453
# Cost after iteration 214000: 0.6931471805599453
# Cost after iteration 215000: 0.6931471805599453
# Cost after iteration 216000: 0.6931471805599453
# Cost after iteration 217000: 0.6931471805599453
# Cost after iteration 218000: 0.6931471805599453
# Cost after iteration 219000: 0.6931471805599453
# Cost after iteration 220000: 0.6931471805599453
# Cost after iteration 221000: 0.6931471805599453
# Cost after iteration 222000: 0.6931471805599453
# Cost after iteration 223000: 0.6931471805599453
# Cost after iteration 224000: 0.6931471805599453
# Cost after iteration 225000: 0.6931471805599453
# Cost after iteration 226000: 0.6931471805599453
# Cost after iteration 227000: 0.6931471805599453
# Cost after iteration 228000: 0.6931471805599453
# Cost after iteration 229000: 0.6931471805599453
# Cost after iteration 230000: 0.6931471805599453
# Cost after iteration 231000: 0.6931471805599453
# Cost after iteration 232000: 0.6931471805599453
# Cost after iteration 233000: 0.6931471805599453
# Cost after iteration 234000: 0.6931471805599453
# Cost after iteration 235000: 0.6931471805599453
# Cost after iteration 236000: 0.6931471805599453
# Cost after iteration 237000: 0.6931471805599453
# Cost after iteration 238000: 0.6931471805599453
# Cost after iteration 239000: 0.6931471805599453
# Cost after iteration 240000: 0.6931471805599453
# Cost after iteration 241000: 0.6931471805599453
# Cost after iteration 242000: 0.6931471805599453
# Cost after iteration 243000: 0.6931471805599453
# Cost after iteration 244000: 0.6931471805599453
# Cost after iteration 245000: 0.6931471805599453
# Cost after iteration 246000: 0.6931471805599453
# Cost after iteration 247000: 0.6931471805599453
# Cost after iteration 248000: 0.6931471805599453
# Cost after iteration 249000: 0.6931471805599453
# Cost after iteration 250000: 0.6931471805599453
# Cost after iteration 251000: 0.6931471805599453
# Cost after iteration 252000: 0.6931471805599453
# Cost after iteration 253000: 0.6931471805599453
# Cost after iteration 254000: 0.6931471805599453
# Cost after iteration 255000: 0.6931471805599453
# Cost after iteration 256000: 0.6931471805599453
# Cost after iteration 257000: 0.6931471805599453
# Cost after iteration 258000: 0.6931471805599453
# Cost after iteration 259000: 0.6931471805599453
# Cost after iteration 260000: 0.6931471805599453
# Cost after iteration 261000: 0.6931471805599453
# Cost after iteration 262000: 0.6931471805599453
# Cost after iteration 263000: 0.6931471805599453
# Cost after iteration 264000: 0.6931471805599453
# Cost after iteration 265000: 0.6931471805599453
# Cost after iteration 266000: 0.6931471805599453
# Cost after iteration 267000: 0.6931471805599453
# Cost after iteration 268000: 0.6931471805599453
# Cost after iteration 269000: 0.6931471805599453
# Cost after iteration 270000: 0.6931471805599453
# Cost after iteration 271000: 0.6931471805599453
# Cost after iteration 272000: 0.6931471805599453
# Cost after iteration 273000: 0.6931471805599453
# Cost after iteration 274000: 0.6931471805599453
# Cost after iteration 275000: 0.6931471805599453
# Cost after iteration 276000: 0.6931471805599453
# Cost after iteration 277000: 0.6931471805599453
# Cost after iteration 278000: 0.6931471805599453
# Cost after iteration 279000: 0.6931471805599453
# Cost after iteration 280000: 0.6931471805599453
# Cost after iteration 281000: 0.6931471805599453
# Cost after iteration 282000: 0.6931471805599453
# Cost after iteration 283000: 0.6931471805599453
# Cost after iteration 284000: 0.6931471805599453
# Cost after iteration 285000: 0.6931471805599453
# Cost after iteration 286000: 0.6931471805599453
# Cost after iteration 287000: 0.6931471805599453
# Cost after iteration 288000: 0.6931471805599453
# Cost after iteration 289000: 0.6931471805599453
# Cost after iteration 290000: 0.6931471805599453
# Cost after iteration 291000: 0.6931471805599453
# Cost after iteration 292000: 0.6931471805599453
# Cost after iteration 293000: 0.6931471805599453
# Cost after iteration 294000: 0.6931471805599453
# Cost after iteration 295000: 0.6931471805599453
# Cost after iteration 296000: 0.6931471805599453
# Cost after iteration 297000: 0.6931471805599453
# Cost after iteration 298000: 0.6931471805599453
# Cost after iteration 299000: 0.6931471805599453
# Cost after iteration 300000: 0.6931471805599453
# Cost after iteration 301000: 0.6931471805599453
# Cost after iteration 302000: 0.6931471805599453
# Cost after iteration 303000: 0.6931471805599453
# Cost after iteration 304000: 0.6931471805599453
# Cost after iteration 305000: 0.6931471805599453
# Cost after iteration 306000: 0.6931471805599453
# Cost after iteration 307000: 0.6931471805599453
# Cost after iteration 308000: 0.6931471805599453
# Cost after iteration 309000: 0.6931471805599453
# Cost after iteration 310000: 0.6931471805599453
# Cost after iteration 311000: 0.6931471805599453
# Cost after iteration 312000: 0.6931471805599453
# Cost after iteration 313000: 0.6931471805599453
# Cost after iteration 314000: 0.6931471805599453
# Cost after iteration 315000: 0.6931471805599453
# Cost after iteration 316000: 0.6931471805599453
# Cost after iteration 317000: 0.6931471805599453
# Cost after iteration 318000: 0.6931471805599453
# Cost after iteration 319000: 0.6931471805599453
# Cost after iteration 320000: 0.6931471805599453
# Cost after iteration 321000: 0.6931471805599453
# Cost after iteration 322000: 0.6931471805599453
# Cost after iteration 323000: 0.6931471805599453
# Cost after iteration 324000: 0.6931471805599453
# Cost after iteration 325000: 0.6931471805599453
# Cost after iteration 326000: 0.6931471805599453
# Cost after iteration 327000: 0.6931471805599453
# Cost after iteration 328000: 0.6931471805599453
# Cost after iteration 329000: 0.6931471805599453
# Cost after iteration 330000: 0.6931471805599453
# Cost after iteration 331000: 0.6931471805599453
# Cost after iteration 332000: 0.6931471805599453
# Cost after iteration 333000: 0.6931471805599453
# Cost after iteration 334000: 0.6931471805599453
# Cost after iteration 335000: 0.6931471805599453
# Cost after iteration 336000: 0.6931471805599453
# Cost after iteration 337000: 0.6931471805599453
# Cost after iteration 338000: 0.6931471805599453
# Cost after iteration 339000: 0.6931471805599453
# Cost after iteration 340000: 0.6931471805599453
# Cost after iteration 341000: 0.6931471805599453
# Cost after iteration 342000: 0.6931471805599453
# Cost after iteration 343000: 0.6931471805599453
# Cost after iteration 344000: 0.6931471805599453
# Cost after iteration 345000: 0.6931471805599453
# Cost after iteration 346000: 0.6931471805599453
# Cost after iteration 347000: 0.6931471805599453
# Cost after iteration 348000: 0.6931471805599453
# Cost after iteration 349000: 0.6931471805599453
# Cost after iteration 350000: 0.6931471805599453
# Cost after iteration 351000: 0.6931471805599453
# Cost after iteration 352000: 0.6931471805599453
# Cost after iteration 353000: 0.6931471805599453
# Cost after iteration 354000: 0.6931471805599453
# Cost after iteration 355000: 0.6931471805599453
# Cost after iteration 356000: 0.6931471805599453
# Cost after iteration 357000: 0.6931471805599453
# Cost after iteration 358000: 0.6931471805599453
# Cost after iteration 359000: 0.6931471805599453
# Cost after iteration 360000: 0.6931471805599453
# Cost after iteration 361000: 0.6931471805599453
# Cost after iteration 362000: 0.6931471805599453
# Cost after iteration 363000: 0.6931471805599453
# Cost after iteration 364000: 0.6931471805599453
# Cost after iteration 365000: 0.6931471805599453
# Cost after iteration 366000: 0.6931471805599453
# Cost after iteration 367000: 0.6931471805599453
# Cost after iteration 368000: 0.6931471805599453
# Cost after iteration 369000: 0.6931471805599453
# Cost after iteration 370000: 0.6931471805599453
# Cost after iteration 371000: 0.6931471805599453
# Cost after iteration 372000: 0.6931471805599453
# Cost after iteration 373000: 0.6931471805599453
# Cost after iteration 374000: 0.6931471805599453
# Cost after iteration 375000: 0.6931471805599453
# Cost after iteration 376000: 0.6931471805599453
# Cost after iteration 377000: 0.6931471805599453
# Cost after iteration 378000: 0.6931471805599453
# Cost after iteration 379000: 0.6931471805599453
# Cost after iteration 380000: 0.6931471805599453
# Cost after iteration 381000: 0.6931471805599453
# Cost after iteration 382000: 0.6931471805599453
# Cost after iteration 383000: 0.6931471805599453
# Cost after iteration 384000: 0.6931471805599453
# Cost after iteration 385000: 0.6931471805599453
# Cost after iteration 386000: 0.6931471805599453
# Cost after iteration 387000: 0.6931471805599453
# Cost after iteration 388000: 0.6931471805599453
# Cost after iteration 389000: 0.6931471805599453
# Cost after iteration 390000: 0.6931471805599453
# Cost after iteration 391000: 0.6931471805599453
# Cost after iteration 392000: 0.6931471805599453
# Cost after iteration 393000: 0.6931471805599453
# Cost after iteration 394000: 0.6931471805599453
# Cost after iteration 395000: 0.6931471805599453
# Cost after iteration 396000: 0.6931471805599453
# Cost after iteration 397000: 0.6931471805599453
# Cost after iteration 398000: 0.6931471805599453
# Cost after iteration 399000: 0.6931471805599453
# Cost after iteration 400000: 0.6931471805599453
# Cost after iteration 401000: 0.6931471805599453
# Cost after iteration 402000: 0.6931471805599453
# Cost after iteration 403000: 0.6931471805599453
# Cost after iteration 404000: 0.6931471805599453
# Cost after iteration 405000: 0.6931471805599453
# Cost after iteration 406000: 0.6931471805599453
# Cost after iteration 407000: 0.6931471805599453
# Cost after iteration 408000: 0.6931471805599453
# Cost after iteration 409000: 0.6931471805599453
# Cost after iteration 410000: 0.6931471805599453
# Cost after iteration 411000: 0.6931471805599453
# Cost after iteration 412000: 0.6931471805599453
# Cost after iteration 413000: 0.6931471805599453
# Cost after iteration 414000: 0.6931471805599453
# Cost after iteration 415000: 0.6931471805599453
# Cost after iteration 416000: 0.6931471805599453
# Cost after iteration 417000: 0.6931471805599453
# Cost after iteration 418000: 0.6931471805599453
# Cost after iteration 419000: 0.6931471805599453
# Cost after iteration 420000: 0.6931471805599453
# Cost after iteration 421000: 0.6931471805599453
# Cost after iteration 422000: 0.6931471805599453
# Cost after iteration 423000: 0.6931471805599453
# Cost after iteration 424000: 0.6931471805599453
# Cost after iteration 425000: 0.6931471805599453
# Cost after iteration 426000: 0.6931471805599453
# Cost after iteration 427000: 0.6931471805599453
# Cost after iteration 428000: 0.6931471805599453
# Cost after iteration 429000: 0.6931471805599453
# Cost after iteration 430000: 0.6931471805599453
# Cost after iteration 431000: 0.6931471805599453
# Cost after iteration 432000: 0.6931471805599453
# Cost after iteration 433000: 0.6931471805599453
# Cost after iteration 434000: 0.6931471805599453
# Cost after iteration 435000: 0.6931471805599453
# Cost after iteration 436000: 0.6931471805599453
# Cost after iteration 437000: 0.6931471805599453
# Cost after iteration 438000: 0.6931471805599453
# Cost after iteration 439000: 0.6931471805599453
# Cost after iteration 440000: 0.6931471805599453
# Cost after iteration 441000: 0.6931471805599453
# Cost after iteration 442000: 0.6931471805599453
# Cost after iteration 443000: 0.6931471805599453
# Cost after iteration 444000: 0.6931471805599453
# Cost after iteration 445000: 0.6931471805599453
# Cost after iteration 446000: 0.6931471805599453
# Cost after iteration 447000: 0.6931471805599453
# Cost after iteration 448000: 0.6931471805599453
# Cost after iteration 449000: 0.6931471805599453
# Cost after iteration 450000: 0.6931471805599453
# Cost after iteration 451000: 0.6931471805599453
# Cost after iteration 452000: 0.6931471805599453
# Cost after iteration 453000: 0.6931471805599453
# Cost after iteration 454000: 0.6931471805599453
# Cost after iteration 455000: 0.6931471805599453
# Cost after iteration 456000: 0.6931471805599453
# Cost after iteration 457000: 0.6931471805599453
# Cost after iteration 458000: 0.6931471805599453
# Cost after iteration 459000: 0.6931471805599453
# Cost after iteration 460000: 0.6931471805599453
# Cost after iteration 461000: 0.6931471805599453
# Cost after iteration 462000: 0.6931471805599453
# Cost after iteration 463000: 0.6931471805599453
# Cost after iteration 464000: 0.6931471805599453
# Cost after iteration 465000: 0.6931471805599453
# Cost after iteration 466000: 0.6931471805599453
# Cost after iteration 467000: 0.6931471805599453
# Cost after iteration 468000: 0.6931471805599453
# Cost after iteration 469000: 0.6931471805599453
# Cost after iteration 470000: 0.6931471805599453
# Cost after iteration 471000: 0.6931471805599453
# Cost after iteration 472000: 0.6931471805599453
# Cost after iteration 473000: 0.6931471805599453
# Cost after iteration 474000: 0.6931471805599453
# Cost after iteration 475000: 0.6931471805599453
# Cost after iteration 476000: 0.6931471805599453
# Cost after iteration 477000: 0.6931471805599453
# Cost after iteration 478000: 0.6931471805599453
# Cost after iteration 479000: 0.6931471805599453
# Cost after iteration 480000: 0.6931471805599453
# Cost after iteration 481000: 0.6931471805599453
# Cost after iteration 482000: 0.6931471805599453
# Cost after iteration 483000: 0.6931471805599453
# Cost after iteration 484000: 0.6931471805599453
# Cost after iteration 485000: 0.6931471805599453
# Cost after iteration 486000: 0.6931471805599453
# Cost after iteration 487000: 0.6931471805599453
# Cost after iteration 488000: 0.6931471805599453
# Cost after iteration 489000: 0.6931471805599453
# Cost after iteration 490000: 0.6931471805599453
# Cost after iteration 491000: 0.6931471805599453
# Cost after iteration 492000: 0.6931471805599453
# Cost after iteration 493000: 0.6931471805599453
# Cost after iteration 494000: 0.6931471805599453
# Cost after iteration 495000: 0.6931471805599453
# Cost after iteration 496000: 0.6931471805599453
# Cost after iteration 497000: 0.6931471805599453
# Cost after iteration 498000: 0.6931471805599453
# Cost after iteration 499000: 0.6931471805599453
# Cost after iteration 500000: 0.6931471805599453
# Cost after iteration 501000: 0.6931471805599453
# Cost after iteration 502000: 0.6931471805599453
# Cost after iteration 503000: 0.6931471805599453
# Cost after iteration 504000: 0.6931471805599453
# Cost after iteration 505000: 0.6931471805599453
# Cost after iteration 506000: 0.6931471805599453
# Cost after iteration 507000: 0.6931471805599453
# Cost after iteration 508000: 0.6931471805599453
# Cost after iteration 509000: 0.6931471805599453
# Cost after iteration 510000: 0.6931471805599453
# Cost after iteration 511000: 0.6931471805599453
# Cost after iteration 512000: 0.6931471805599453
# Cost after iteration 513000: 0.6931471805599453
# Cost after iteration 514000: 0.6931471805599453
# Cost after iteration 515000: 0.6931471805599453
# Cost after iteration 516000: 0.6931471805599453
# Cost after iteration 517000: 0.6931471805599453
# Cost after iteration 518000: 0.6931471805599453
# Cost after iteration 519000: 0.6931471805599453
# Cost after iteration 520000: 0.6931471805599453
# Cost after iteration 521000: 0.6931471805599453
# Cost after iteration 522000: 0.6931471805599453
# Cost after iteration 523000: 0.6931471805599453
# Cost after iteration 524000: 0.6931471805599453
# Cost after iteration 525000: 0.6931471805599453
# Cost after iteration 526000: 0.6931471805599453
# Cost after iteration 527000: 0.6931471805599453
# Cost after iteration 528000: 0.6931471805599453
# Cost after iteration 529000: 0.6931471805599453
# Cost after iteration 530000: 0.6931471805599453
# Cost after iteration 531000: 0.6931471805599453
# Cost after iteration 532000: 0.6931471805599453
# Cost after iteration 533000: 0.6931471805599453
# Cost after iteration 534000: 0.6931471805599453
# Cost after iteration 535000: 0.6931471805599453
# Cost after iteration 536000: 0.6931471805599453
# Cost after iteration 537000: 0.6931471805599453
# Cost after iteration 538000: 0.6931471805599453
# Cost after iteration 539000: 0.6931471805599453
# Cost after iteration 540000: 0.6931471805599453
# Cost after iteration 541000: 0.6931471805599453
# Cost after iteration 542000: 0.6931471805599453
# Cost after iteration 543000: 0.6931471805599453
# Cost after iteration 544000: 0.6931471805599453
# Cost after iteration 545000: 0.6931471805599453
# Cost after iteration 546000: 0.6931471805599453
# Cost after iteration 547000: 0.6931471805599453
# Cost after iteration 548000: 0.6931471805599453
# Cost after iteration 549000: 0.6931471805599453
# Cost after iteration 550000: 0.6931471805599453
# Cost after iteration 551000: 0.6931471805599453
# Cost after iteration 552000: 0.6931471805599453
# Cost after iteration 553000: 0.6931471805599453
# Cost after iteration 554000: 0.6931471805599453
# Cost after iteration 555000: 0.6931471805599453
# Cost after iteration 556000: 0.6931471805599453
# Cost after iteration 557000: 0.6931471805599453
# Cost after iteration 558000: 0.6931471805599453
# Cost after iteration 559000: 0.6931471805599453
# Cost after iteration 560000: 0.6931471805599453
# Cost after iteration 561000: 0.6931471805599453
# Cost after iteration 562000: 0.6931471805599453
# Cost after iteration 563000: 0.6931471805599453
# Cost after iteration 564000: 0.6931471805599453
# Cost after iteration 565000: 0.6931471805599453
# Cost after iteration 566000: 0.6931471805599453
# Cost after iteration 567000: 0.6931471805599453
# Cost after iteration 568000: 0.6931471805599453
# Cost after iteration 569000: 0.6931471805599453
# Cost after iteration 570000: 0.6931471805599453
# Cost after iteration 571000: 0.6931471805599453
# Cost after iteration 572000: 0.6931471805599453
# Cost after iteration 573000: 0.6931471805599453
# Cost after iteration 574000: 0.6931471805599453
# Cost after iteration 575000: 0.6931471805599453
# Cost after iteration 576000: 0.6931471805599453
# Cost after iteration 577000: 0.6931471805599453
# Cost after iteration 578000: 0.6931471805599453
# Cost after iteration 579000: 0.6931471805599453
# Cost after iteration 580000: 0.6931471805599453
# Cost after iteration 581000: 0.6931471805599453
# Cost after iteration 582000: 0.6931471805599453
# Cost after iteration 583000: 0.6931471805599453
# Cost after iteration 584000: 0.6931471805599453
# Cost after iteration 585000: 0.6931471805599453
# Cost after iteration 586000: 0.6931471805599453
# Cost after iteration 587000: 0.6931471805599453
# Cost after iteration 588000: 0.6931471805599453
# Cost after iteration 589000: 0.6931471805599453
# Cost after iteration 590000: 0.6931471805599453
# Cost after iteration 591000: 0.6931471805599453
# Cost after iteration 592000: 0.6931471805599453
# Cost after iteration 593000: 0.6931471805599453
# Cost after iteration 594000: 0.6931471805599453
# Cost after iteration 595000: 0.6931471805599453
# Cost after iteration 596000: 0.6931471805599453
# Cost after iteration 597000: 0.6931471805599453
# Cost after iteration 598000: 0.6931471805599453
# Cost after iteration 599000: 0.6931471805599453
# Cost after iteration 600000: 0.6931471805599453
# Cost after iteration 601000: 0.6931471805599453
# Cost after iteration 602000: 0.6931471805599453
# Cost after iteration 603000: 0.6931471805599453
# Cost after iteration 604000: 0.6931471805599453
# Cost after iteration 605000: 0.6931471805599453
# Cost after iteration 606000: 0.6931471805599453
# Cost after iteration 607000: 0.6931471805599453
# Cost after iteration 608000: 0.6931471805599453
# Cost after iteration 609000: 0.6931471805599453
# Cost after iteration 610000: 0.6931471805599453
# Cost after iteration 611000: 0.6931471805599453
# Cost after iteration 612000: 0.6931471805599453
# Cost after iteration 613000: 0.6931471805599453
# Cost after iteration 614000: 0.6931471805599453
# Cost after iteration 615000: 0.6931471805599453
# Cost after iteration 616000: 0.6931471805599453
# Cost after iteration 617000: 0.6931471805599453
# Cost after iteration 618000: 0.6931471805599453
# Cost after iteration 619000: 0.6931471805599453
# Cost after iteration 620000: 0.6931471805599453
# Cost after iteration 621000: 0.6931471805599453
# Cost after iteration 622000: 0.6931471805599453
# Cost after iteration 623000: 0.6931471805599453
# Cost after iteration 624000: 0.6931471805599453
# Cost after iteration 625000: 0.6931471805599453
# Cost after iteration 626000: 0.6931471805599453
# Cost after iteration 627000: 0.6931471805599453
# Cost after iteration 628000: 0.6931471805599453
# Cost after iteration 629000: 0.6931471805599453
# Cost after iteration 630000: 0.6931471805599453
# Cost after iteration 631000: 0.6931471805599453
# Cost after iteration 632000: 0.6931471805599453
# Cost after iteration 633000: 0.6931471805599453
# Cost after iteration 634000: 0.6931471805599453
# Cost after iteration 635000: 0.6931471805599453
# Cost after iteration 636000: 0.6931471805599453
# Cost after iteration 637000: 0.6931471805599453
# Cost after iteration 638000: 0.6931471805599453
# Cost after iteration 639000: 0.6931471805599453
# Cost after iteration 640000: 0.6931471805599453
# Cost after iteration 641000: 0.6931471805599453
# Cost after iteration 642000: 0.6931471805599453
# Cost after iteration 643000: 0.6931471805599453
# Cost after iteration 644000: 0.6931471805599453
# Cost after iteration 645000: 0.6931471805599453
# Cost after iteration 646000: 0.6931471805599453
# Cost after iteration 647000: 0.6931471805599453
# Cost after iteration 648000: 0.6931471805599453
# Cost after iteration 649000: 0.6931471805599453
# Cost after iteration 650000: 0.6931471805599453
# Cost after iteration 651000: 0.6931471805599453
# Cost after iteration 652000: 0.6931471805599453
# Cost after iteration 653000: 0.6931471805599453
# Cost after iteration 654000: 0.6931471805599453
# Cost after iteration 655000: 0.6931471805599453
# Cost after iteration 656000: 0.6931471805599453
# Cost after iteration 657000: 0.6931471805599453
# Cost after iteration 658000: 0.6931471805599453
# Cost after iteration 659000: 0.6931471805599453
# Cost after iteration 660000: 0.6931471805599453
# Cost after iteration 661000: 0.6931471805599453
# Cost after iteration 662000: 0.6931471805599453
# Cost after iteration 663000: 0.6931471805599453
# Cost after iteration 664000: 0.6931471805599453
# Cost after iteration 665000: 0.6931471805599453
# Cost after iteration 666000: 0.6931471805599453
# Cost after iteration 667000: 0.6931471805599453
# Cost after iteration 668000: 0.6931471805599453
# Cost after iteration 669000: 0.6931471805599453
# Cost after iteration 670000: 0.6931471805599453
# Cost after iteration 671000: 0.6931471805599453
# Cost after iteration 672000: 0.6931471805599453
# Cost after iteration 673000: 0.6931471805599453
# Cost after iteration 674000: 0.6931471805599453
# Cost after iteration 675000: 0.6931471805599453
# Cost after iteration 676000: 0.6931471805599453
# Cost after iteration 677000: 0.6931471805599453
# Cost after iteration 678000: 0.6931471805599453
# Cost after iteration 679000: 0.6931471805599453
# Cost after iteration 680000: 0.6931471805599453
# Cost after iteration 681000: 0.6931471805599453
# Cost after iteration 682000: 0.6931471805599453
# Cost after iteration 683000: 0.6931471805599453
# Cost after iteration 684000: 0.6931471805599453
# Cost after iteration 685000: 0.6931471805599453
# Cost after iteration 686000: 0.6931471805599453
# Cost after iteration 687000: 0.6931471805599453
# Cost after iteration 688000: 0.6931471805599453
# Cost after iteration 689000: 0.6931471805599453
# Cost after iteration 690000: 0.6931471805599453
# Cost after iteration 691000: 0.6931471805599453
# Cost after iteration 692000: 0.6931471805599453
# Cost after iteration 693000: 0.6931471805599453
# Cost after iteration 694000: 0.6931471805599453
# Cost after iteration 695000: 0.6931471805599453
# Cost after iteration 696000: 0.6931471805599453
# Cost after iteration 697000: 0.6931471805599453
# Cost after iteration 698000: 0.6931471805599453
# Cost after iteration 699000: 0.6931471805599453
# Cost after iteration 700000: 0.6931471805599453
# Cost after iteration 701000: 0.6931471805599453
# Cost after iteration 702000: 0.6931471805599453
# Cost after iteration 703000: 0.6931471805599453
# Cost after iteration 704000: 0.6931471805599453
# Cost after iteration 705000: 0.6931471805599453
# Cost after iteration 706000: 0.6931471805599453
# Cost after iteration 707000: 0.6931471805599453
# Cost after iteration 708000: 0.6931471805599453
# Cost after iteration 709000: 0.6931471805599453
# Cost after iteration 710000: 0.6931471805599453
# Cost after iteration 711000: 0.6931471805599453
# Cost after iteration 712000: 0.6931471805599453
# Cost after iteration 713000: 0.6931471805599453
# Cost after iteration 714000: 0.6931471805599453
# Cost after iteration 715000: 0.6931471805599453
# Cost after iteration 716000: 0.6931471805599453
# Cost after iteration 717000: 0.6931471805599453
# Cost after iteration 718000: 0.6931471805599453
# Cost after iteration 719000: 0.6931471805599453
# Cost after iteration 720000: 0.6931471805599453
# Cost after iteration 721000: 0.6931471805599453
# Cost after iteration 722000: 0.6931471805599453
# Cost after iteration 723000: 0.6931471805599453
# Cost after iteration 724000: 0.6931471805599453
# Cost after iteration 725000: 0.6931471805599453
# Cost after iteration 726000: 0.6931471805599453
# Cost after iteration 727000: 0.6931471805599453
# Cost after iteration 728000: 0.6931471805599453
# Cost after iteration 729000: 0.6931471805599453
# Cost after iteration 730000: 0.6931471805599453
# Cost after iteration 731000: 0.6931471805599453
# Cost after iteration 732000: 0.6931471805599453
# Cost after iteration 733000: 0.6931471805599453
# Cost after iteration 734000: 0.6931471805599453
# Cost after iteration 735000: 0.6931471805599453
# Cost after iteration 736000: 0.6931471805599453
# Cost after iteration 737000: 0.6931471805599453
# Cost after iteration 738000: 0.6931471805599453
# Cost after iteration 739000: 0.6931471805599453
# Cost after iteration 740000: 0.6931471805599453
# Cost after iteration 741000: 0.6931471805599453
# Cost after iteration 742000: 0.6931471805599453
# Cost after iteration 743000: 0.6931471805599453
# Cost after iteration 744000: 0.6931471805599453
# Cost after iteration 745000: 0.6931471805599453
# Cost after iteration 746000: 0.6931471805599453
# Cost after iteration 747000: 0.6931471805599453
# Cost after iteration 748000: 0.6931471805599453
# Cost after iteration 749000: 0.6931471805599453
# Cost after iteration 750000: 0.6931471805599453
# Cost after iteration 751000: 0.6931471805599453
# Cost after iteration 752000: 0.6931471805599453
# Cost after iteration 753000: 0.6931471805599453
# Cost after iteration 754000: 0.6931471805599453
# Cost after iteration 755000: 0.6931471805599453
# Cost after iteration 756000: 0.6931471805599453
# Cost after iteration 757000: 0.6931471805599453
# Cost after iteration 758000: 0.6931471805599453
# Cost after iteration 759000: 0.6931471805599453
# Cost after iteration 760000: 0.6931471805599453
# Cost after iteration 761000: 0.6931471805599453
# Cost after iteration 762000: 0.6931471805599453
# Cost after iteration 763000: 0.6931471805599453
# Cost after iteration 764000: 0.6931471805599453
# Cost after iteration 765000: 0.6931471805599453
# Cost after iteration 766000: 0.6931471805599453
# Cost after iteration 767000: 0.6931471805599453
# Cost after iteration 768000: 0.6931471805599453
# Cost after iteration 769000: 0.6931471805599453
# Cost after iteration 770000: 0.6931471805599453
# Cost after iteration 771000: 0.6931471805599453
# Cost after iteration 772000: 0.6931471805599453
# Cost after iteration 773000: 0.6931471805599453
# Cost after iteration 774000: 0.6931471805599453
# Cost after iteration 775000: 0.6931471805599453
# Cost after iteration 776000: 0.6931471805599453
# Cost after iteration 777000: 0.6931471805599453
# Cost after iteration 778000: 0.6931471805599453
# Cost after iteration 779000: 0.6931471805599453
# Cost after iteration 780000: 0.6931471805599453
# Cost after iteration 781000: 0.6931471805599453
# Cost after iteration 782000: 0.6931471805599453
# Cost after iteration 783000: 0.6931471805599453
# Cost after iteration 784000: 0.6931471805599453
# Cost after iteration 785000: 0.6931471805599453
# Cost after iteration 786000: 0.6931471805599453
# Cost after iteration 787000: 0.6931471805599453
# Cost after iteration 788000: 0.6931471805599453
# Cost after iteration 789000: 0.6931471805599453
# Cost after iteration 790000: 0.6931471805599453
# Cost after iteration 791000: 0.6931471805599453
# Cost after iteration 792000: 0.6931471805599453
# Cost after iteration 793000: 0.6931471805599453
# Cost after iteration 794000: 0.6931471805599453
# Cost after iteration 795000: 0.6931471805599453
# Cost after iteration 796000: 0.6931471805599453
# Cost after iteration 797000: 0.6931471805599453
# Cost after iteration 798000: 0.6931471805599453
# Cost after iteration 799000: 0.6931471805599453
# Cost after iteration 800000: 0.6931471805599453
# Cost after iteration 801000: 0.6931471805599453
# Cost after iteration 802000: 0.6931471805599453
# Cost after iteration 803000: 0.6931471805599453
# Cost after iteration 804000: 0.6931471805599453
# Cost after iteration 805000: 0.6931471805599453
# Cost after iteration 806000: 0.6931471805599453
# Cost after iteration 807000: 0.6931471805599453
# Cost after iteration 808000: 0.6931471805599453
# Cost after iteration 809000: 0.6931471805599453
# Cost after iteration 810000: 0.6931471805599453
# Cost after iteration 811000: 0.6931471805599453
# Cost after iteration 812000: 0.6931471805599453
# Cost after iteration 813000: 0.6931471805599453
# Cost after iteration 814000: 0.6931471805599453
# Cost after iteration 815000: 0.6931471805599453
# Cost after iteration 816000: 0.6931471805599453
# Cost after iteration 817000: 0.6931471805599453
# Cost after iteration 818000: 0.6931471805599453
# Cost after iteration 819000: 0.6931471805599453
# Cost after iteration 820000: 0.6931471805599453
# Cost after iteration 821000: 0.6931471805599453
# Cost after iteration 822000: 0.6931471805599453
# Cost after iteration 823000: 0.6931471805599453
# Cost after iteration 824000: 0.6931471805599453
# Cost after iteration 825000: 0.6931471805599453
# Cost after iteration 826000: 0.6931471805599453
# Cost after iteration 827000: 0.6931471805599453
# Cost after iteration 828000: 0.6931471805599453
# Cost after iteration 829000: 0.6931471805599453
# Cost after iteration 830000: 0.6931471805599453
# Cost after iteration 831000: 0.6931471805599453
# Cost after iteration 832000: 0.6931471805599453
# Cost after iteration 833000: 0.6931471805599453
# Cost after iteration 834000: 0.6931471805599453
# Cost after iteration 835000: 0.6931471805599453
# Cost after iteration 836000: 0.6931471805599453
# Cost after iteration 837000: 0.6931471805599453
# Cost after iteration 838000: 0.6931471805599453
# Cost after iteration 839000: 0.6931471805599453
# Cost after iteration 840000: 0.6931471805599453
# Cost after iteration 841000: 0.6931471805599453
# Cost after iteration 842000: 0.6931471805599453
# Cost after iteration 843000: 0.6931471805599453
# Cost after iteration 844000: 0.6931471805599453
# Cost after iteration 845000: 0.6931471805599453
# Cost after iteration 846000: 0.6931471805599453
# Cost after iteration 847000: 0.6931471805599453
# Cost after iteration 848000: 0.6931471805599453
# Cost after iteration 849000: 0.6931471805599453
# Cost after iteration 850000: 0.6931471805599453
# Cost after iteration 851000: 0.6931471805599453
# Cost after iteration 852000: 0.6931471805599453
# Cost after iteration 853000: 0.6931471805599453
# Cost after iteration 854000: 0.6931471805599453
# Cost after iteration 855000: 0.6931471805599453
# Cost after iteration 856000: 0.6931471805599453
# Cost after iteration 857000: 0.6931471805599453
# Cost after iteration 858000: 0.6931471805599453
# Cost after iteration 859000: 0.6931471805599453
# Cost after iteration 860000: 0.6931471805599453
# Cost after iteration 861000: 0.6931471805599453
# Cost after iteration 862000: 0.6931471805599453
# Cost after iteration 863000: 0.6931471805599453
# Cost after iteration 864000: 0.6931471805599453
# Cost after iteration 865000: 0.6931471805599453
# Cost after iteration 866000: 0.6931471805599453
# Cost after iteration 867000: 0.6931471805599453
# Cost after iteration 868000: 0.6931471805599453
# Cost after iteration 869000: 0.6931471805599453
# Cost after iteration 870000: 0.6931471805599453
# Cost after iteration 871000: 0.6931471805599453
# Cost after iteration 872000: 0.6931471805599453
# Cost after iteration 873000: 0.6931471805599453
# Cost after iteration 874000: 0.6931471805599453
# Cost after iteration 875000: 0.6931471805599453
# Cost after iteration 876000: 0.6931471805599453
# Cost after iteration 877000: 0.6931471805599453
# Cost after iteration 878000: 0.6931471805599453
# Cost after iteration 879000: 0.6931471805599453
# Cost after iteration 880000: 0.6931471805599453
# Cost after iteration 881000: 0.6931471805599453
# Cost after iteration 882000: 0.6931471805599453
# Cost after iteration 883000: 0.6931471805599453
# Cost after iteration 884000: 0.6931471805599453
# Cost after iteration 885000: 0.6931471805599453
# Cost after iteration 886000: 0.6931471805599453
# Cost after iteration 887000: 0.6931471805599453
# Cost after iteration 888000: 0.6931471805599453
# Cost after iteration 889000: 0.6931471805599453
# Cost after iteration 890000: 0.6931471805599453
# Cost after iteration 891000: 0.6931471805599453
# Cost after iteration 892000: 0.6931471805599453
# Cost after iteration 893000: 0.6931471805599453
# Cost after iteration 894000: 0.6931471805599453
# Cost after iteration 895000: 0.6931471805599453
# Cost after iteration 896000: 0.6931471805599453
# Cost after iteration 897000: 0.6931471805599453
# Cost after iteration 898000: 0.6931471805599453
# Cost after iteration 899000: 0.6931471805599453
# Cost after iteration 900000: 0.6931471805599453
# Cost after iteration 901000: 0.6931471805599453
# Cost after iteration 902000: 0.6931471805599453
# Cost after iteration 903000: 0.6931471805599453
# Cost after iteration 904000: 0.6931471805599453
# Cost after iteration 905000: 0.6931471805599453
# Cost after iteration 906000: 0.6931471805599453
# Cost after iteration 907000: 0.6931471805599453
# Cost after iteration 908000: 0.6931471805599453
# Cost after iteration 909000: 0.6931471805599453
# Cost after iteration 910000: 0.6931471805599453
# Cost after iteration 911000: 0.6931471805599453
# Cost after iteration 912000: 0.6931471805599453
# Cost after iteration 913000: 0.6931471805599453
# Cost after iteration 914000: 0.6931471805599453
# Cost after iteration 915000: 0.6931471805599453
# Cost after iteration 916000: 0.6931471805599453
# Cost after iteration 917000: 0.6931471805599453
# Cost after iteration 918000: 0.6931471805599453
# Cost after iteration 919000: 0.6931471805599453
# Cost after iteration 920000: 0.6931471805599453
# Cost after iteration 921000: 0.6931471805599453
# Cost after iteration 922000: 0.6931471805599453
# Cost after iteration 923000: 0.6931471805599453
# Cost after iteration 924000: 0.6931471805599453
# Cost after iteration 925000: 0.6931471805599453
# Cost after iteration 926000: 0.6931471805599453
# Cost after iteration 927000: 0.6931471805599453
# Cost after iteration 928000: 0.6931471805599453
# Cost after iteration 929000: 0.6931471805599453
# Cost after iteration 930000: 0.6931471805599453
# Cost after iteration 931000: 0.6931471805599453
# Cost after iteration 932000: 0.6931471805599453
# Cost after iteration 933000: 0.6931471805599453
# Cost after iteration 934000: 0.6931471805599453
# Cost after iteration 935000: 0.6931471805599453
# Cost after iteration 936000: 0.6931471805599453
# Cost after iteration 937000: 0.6931471805599453
# Cost after iteration 938000: 0.6931471805599453
# Cost after iteration 939000: 0.6931471805599453
# Cost after iteration 940000: 0.6931471805599453
# Cost after iteration 941000: 0.6931471805599453
# Cost after iteration 942000: 0.6931471805599453
# Cost after iteration 943000: 0.6931471805599453
# Cost after iteration 944000: 0.6931471805599453
# Cost after iteration 945000: 0.6931471805599453
# Cost after iteration 946000: 0.6931471805599453
# Cost after iteration 947000: 0.6931471805599453
# Cost after iteration 948000: 0.6931471805599453
# Cost after iteration 949000: 0.6931471805599453
# Cost after iteration 950000: 0.6931471805599453
# Cost after iteration 951000: 0.6931471805599453
# Cost after iteration 952000: 0.6931471805599453
# Cost after iteration 953000: 0.6931471805599453
# Cost after iteration 954000: 0.6931471805599453
# Cost after iteration 955000: 0.6931471805599453
# Cost after iteration 956000: 0.6931471805599453
# Cost after iteration 957000: 0.6931471805599453
# Cost after iteration 958000: 0.6931471805599453
# Cost after iteration 959000: 0.6931471805599453
# Cost after iteration 960000: 0.6931471805599453
# Cost after iteration 961000: 0.6931471805599453
# Cost after iteration 962000: 0.6931471805599453
# Cost after iteration 963000: 0.6931471805599453
# Cost after iteration 964000: 0.6931471805599453
# Cost after iteration 965000: 0.6931471805599453
# Cost after iteration 966000: 0.6931471805599453
# Cost after iteration 967000: 0.6931471805599453
# Cost after iteration 968000: 0.6931471805599453
# Cost after iteration 969000: 0.6931471805599453
# Cost after iteration 970000: 0.6931471805599453
# Cost after iteration 971000: 0.6931471805599453
# Cost after iteration 972000: 0.6931471805599453
# Cost after iteration 973000: 0.6931471805599453
# Cost after iteration 974000: 0.6931471805599453
# Cost after iteration 975000: 0.6931471805599453
# Cost after iteration 976000: 0.6931471805599453
# Cost after iteration 977000: 0.6931471805599453
# Cost after iteration 978000: 0.6931471805599453
# Cost after iteration 979000: 0.6931471805599453
# Cost after iteration 980000: 0.6931471805599453
# Cost after iteration 981000: 0.6931471805599453
# Cost after iteration 982000: 0.6931471805599453
# Cost after iteration 983000: 0.6931471805599453
# Cost after iteration 984000: 0.6931471805599453
# Cost after iteration 985000: 0.6931471805599453
# Cost after iteration 986000: 0.6931471805599453
# Cost after iteration 987000: 0.6931471805599453
# Cost after iteration 988000: 0.6931471805599453
# Cost after iteration 989000: 0.6931471805599453
# Cost after iteration 990000: 0.6931471805599453
# Cost after iteration 991000: 0.6931471805599453
# Cost after iteration 992000: 0.6931471805599453
# Cost after iteration 993000: 0.6931471805599453
# Cost after iteration 994000: 0.6931471805599453
# Cost after iteration 995000: 0.6931471805599453
# Cost after iteration 996000: 0.6931471805599453
# Cost after iteration 997000: 0.6931471805599453
# Cost after iteration 998000: 0.6931471805599453
# Cost after iteration 999000: 0.6931471805599453
# Cost after iteration 1000000: 0.6931471805599453
# Cost after iteration 1001000: 0.6931471805599453
# ...
# Cost after iteration 2198000: 0.6931471805599453
# Cost after iteration 2199000: 0.6931471805599453
# Cost after iteration 2200000: 0.6931471805599453
# Cost after iteration 2201000: 0.6931471805599453
# Cost after iteration 2202000: 0.6931471805599453
# Cost after iteration 2203000: 0.6931471805599453
# Cost after iteration 2204000: 0.6931471805599453
# Cost after iteration 2205000: 0.6931471805599453
# Cost after iteration 2206000: 0.6931471805599453
# Cost after iteration 2207000: 0.6931471805599453
# Cost after iteration 2208000: 0.6931471805599453
# Cost after iteration 2209000: 0.6931471805599453
# Cost after iteration 2210000: 0.6931471805599453
# Cost after iteration 2211000: 0.6931471805599453
# Cost after iteration 2212000: 0.6931471805599453
# Cost after iteration 2213000: 0.6931471805599453
# Cost after iteration 2214000: 0.6931471805599453
# Cost after iteration 2215000: 0.6931471805599453
# Cost after iteration 2216000: 0.6931471805599453
# Cost after iteration 2217000: 0.6931471805599453
# Cost after iteration 2218000: 0.6931471805599453
# Cost after iteration 2219000: 0.6931471805599453
# Cost after iteration 2220000: 0.6931471805599453
# Cost after iteration 2221000: 0.6931471805599453
# Cost after iteration 2222000: 0.6931471805599453
# Cost after iteration 2223000: 0.6931471805599453
# Cost after iteration 2224000: 0.6931471805599453
# Cost after iteration 2225000: 0.6931471805599453
# Cost after iteration 2226000: 0.6931471805599453
# Cost after iteration 2227000: 0.6931471805599453
# Cost after iteration 2228000: 0.6931471805599453
# Cost after iteration 2229000: 0.6931471805599453
# Cost after iteration 2230000: 0.6931471805599453
# Cost after iteration 2231000: 0.6931471805599453
# Cost after iteration 2232000: 0.6931471805599453
# Cost after iteration 2233000: 0.6931471805599453
# Cost after iteration 2234000: 0.6931471805599453
# Cost after iteration 2235000: 0.6931471805599453
# Cost after iteration 2236000: 0.6931471805599453
# Cost after iteration 2237000: 0.6931471805599453
# Cost after iteration 2238000: 0.6931471805599453
# Cost after iteration 2239000: 0.6931471805599453
# Cost after iteration 2240000: 0.6931471805599453
# Cost after iteration 2241000: 0.6931471805599453
# Cost after iteration 2242000: 0.6931471805599453
# Cost after iteration 2243000: 0.6931471805599453
# Cost after iteration 2244000: 0.6931471805599453
# Cost after iteration 2245000: 0.6931471805599453
# Cost after iteration 2246000: 0.6931471805599453
# Cost after iteration 2247000: 0.6931471805599453
# Cost after iteration 2248000: 0.6931471805599453
# Cost after iteration 2249000: 0.6931471805599453
# Cost after iteration 2250000: 0.6931471805599453
# Cost after iteration 2251000: 0.6931471805599453
# Cost after iteration 2252000: 0.6931471805599453
# Cost after iteration 2253000: 0.6931471805599453
# Cost after iteration 2254000: 0.6931471805599453
# Cost after iteration 2255000: 0.6931471805599453
# Cost after iteration 2256000: 0.6931471805599453
# Cost after iteration 2257000: 0.6931471805599453
# Cost after iteration 2258000: 0.6931471805599453
# Cost after iteration 2259000: 0.6931471805599453
# Cost after iteration 2260000: 0.6931471805599453
# Cost after iteration 2261000: 0.6931471805599453
# Cost after iteration 2262000: 0.6931471805599453
# Cost after iteration 2263000: 0.6931471805599453
# Cost after iteration 2264000: 0.6931471805599453
# Cost after iteration 2265000: 0.6931471805599453
# Cost after iteration 2266000: 0.6931471805599453
# Cost after iteration 2267000: 0.6931471805599453
# Cost after iteration 2268000: 0.6931471805599453
# Cost after iteration 2269000: 0.6931471805599453
# Cost after iteration 2270000: 0.6931471805599453
# Cost after iteration 2271000: 0.6931471805599453
# Cost after iteration 2272000: 0.6931471805599453
# Cost after iteration 2273000: 0.6931471805599453
# Cost after iteration 2274000: 0.6931471805599453
# Cost after iteration 2275000: 0.6931471805599453
# Cost after iteration 2276000: 0.6931471805599453
# Cost after iteration 2277000: 0.6931471805599453
# Cost after iteration 2278000: 0.6931471805599453
# Cost after iteration 2279000: 0.6931471805599453
# Cost after iteration 2280000: 0.6931471805599453
# Cost after iteration 2281000: 0.6931471805599453
# Cost after iteration 2282000: 0.6931471805599453
# Cost after iteration 2283000: 0.6931471805599453
# Cost after iteration 2284000: 0.6931471805599453
# Cost after iteration 2285000: 0.6931471805599453
# Cost after iteration 2286000: 0.6931471805599453
# Cost after iteration 2287000: 0.6931471805599453
# Cost after iteration 2288000: 0.6931471805599453
# Cost after iteration 2289000: 0.6931471805599453
# Cost after iteration 2290000: 0.6931471805599453
# Cost after iteration 2291000: 0.6931471805599453
# Cost after iteration 2292000: 0.6931471805599453
# Cost after iteration 2293000: 0.6931471805599453
# Cost after iteration 2294000: 0.6931471805599453
# Cost after iteration 2295000: 0.6931471805599453
# Cost after iteration 2296000: 0.6931471805599453
# Cost after iteration 2297000: 0.6931471805599453
# Cost after iteration 2298000: 0.6931471805599453
# Cost after iteration 2299000: 0.6931471805599453
# Cost after iteration 2300000: 0.6931471805599453
# Cost after iteration 2301000: 0.6931471805599453
# Cost after iteration 2302000: 0.6931471805599453
# Cost after iteration 2303000: 0.6931471805599453
# Cost after iteration 2304000: 0.6931471805599453
# Cost after iteration 2305000: 0.6931471805599453
# Cost after iteration 2306000: 0.6931471805599453
# Cost after iteration 2307000: 0.6931471805599453
# Cost after iteration 2308000: 0.6931471805599453
# Cost after iteration 2309000: 0.6931471805599453
# Cost after iteration 2310000: 0.6931471805599453
# Cost after iteration 2311000: 0.6931471805599453
# Cost after iteration 2312000: 0.6931471805599453
# Cost after iteration 2313000: 0.6931471805599453
# Cost after iteration 2314000: 0.6931471805599453
# Cost after iteration 2315000: 0.6931471805599453
# Cost after iteration 2316000: 0.6931471805599453
# Cost after iteration 2317000: 0.6931471805599453
# Cost after iteration 2318000: 0.6931471805599453
# Cost after iteration 2319000: 0.6931471805599453
# Cost after iteration 2320000: 0.6931471805599453
# Cost after iteration 2321000: 0.6931471805599453
# Cost after iteration 2322000: 0.6931471805599453
# Cost after iteration 2323000: 0.6931471805599453
# Cost after iteration 2324000: 0.6931471805599453
# Cost after iteration 2325000: 0.6931471805599453
# Cost after iteration 2326000: 0.6931471805599453
# Cost after iteration 2327000: 0.6931471805599453
# Cost after iteration 2328000: 0.6931471805599453
# Cost after iteration 2329000: 0.6931471805599453
# Cost after iteration 2330000: 0.6931471805599453
# Cost after iteration 2331000: 0.6931471805599453
# Cost after iteration 2332000: 0.6931471805599453
# Cost after iteration 2333000: 0.6931471805599453
# Cost after iteration 2334000: 0.6931471805599453
# Cost after iteration 2335000: 0.6931471805599453
# Cost after iteration 2336000: 0.6931471805599453
# Cost after iteration 2337000: 0.6931471805599453
# Cost after iteration 2338000: 0.6931471805599453
# Cost after iteration 2339000: 0.6931471805599453
# Cost after iteration 2340000: 0.6931471805599453
# Cost after iteration 2341000: 0.6931471805599453
# Cost after iteration 2342000: 0.6931471805599453
# Cost after iteration 2343000: 0.6931471805599453
# Cost after iteration 2344000: 0.6931471805599453
# Cost after iteration 2345000: 0.6931471805599453
# Cost after iteration 2346000: 0.6931471805599453
# Cost after iteration 2347000: 0.6931471805599453
# Cost after iteration 2348000: 0.6931471805599453
# Cost after iteration 2349000: 0.6931471805599453
# Cost after iteration 2350000: 0.6931471805599453
# Cost after iteration 2351000: 0.6931471805599453
# Cost after iteration 2352000: 0.6931471805599453
# Cost after iteration 2353000: 0.6931471805599453
# Cost after iteration 2354000: 0.6931471805599453
# Cost after iteration 2355000: 0.6931471805599453
# Cost after iteration 2356000: 0.6931471805599453
# Cost after iteration 2357000: 0.6931471805599453
# Cost after iteration 2358000: 0.6931471805599453
# Cost after iteration 2359000: 0.6931471805599453
# Cost after iteration 2360000: 0.6931471805599453
# Cost after iteration 2361000: 0.6931471805599453
# Cost after iteration 2362000: 0.6931471805599453
# Cost after iteration 2363000: 0.6931471805599453
# Cost after iteration 2364000: 0.6931471805599453
# Cost after iteration 2365000: 0.6931471805599453
# Cost after iteration 2366000: 0.6931471805599453
# Cost after iteration 2367000: 0.6931471805599453
# Cost after iteration 2368000: 0.6931471805599453
# Cost after iteration 2369000: 0.6931471805599453
# Cost after iteration 2370000: 0.6931471805599453
# Cost after iteration 2371000: 0.6931471805599453
# Cost after iteration 2372000: 0.6931471805599453
# Cost after iteration 2373000: 0.6931471805599453
# Cost after iteration 2374000: 0.6931471805599453
# Cost after iteration 2375000: 0.6931471805599453
# Cost after iteration 2376000: 0.6931471805599453
# Cost after iteration 2377000: 0.6931471805599453
# Cost after iteration 2378000: 0.6931471805599453
# Cost after iteration 2379000: 0.6931471805599453
# Cost after iteration 2380000: 0.6931471805599453
# Cost after iteration 2381000: 0.6931471805599453
# Cost after iteration 2382000: 0.6931471805599453
# Cost after iteration 2383000: 0.6931471805599453
# Cost after iteration 2384000: 0.6931471805599453
# Cost after iteration 2385000: 0.6931471805599453
# Cost after iteration 2386000: 0.6931471805599453
# Cost after iteration 2387000: 0.6931471805599453
# Cost after iteration 2388000: 0.6931471805599453
# Cost after iteration 2389000: 0.6931471805599453
# Cost after iteration 2390000: 0.6931471805599453
# Cost after iteration 2391000: 0.6931471805599453
# Cost after iteration 2392000: 0.6931471805599453
# Cost after iteration 2393000: 0.6931471805599453
# Cost after iteration 2394000: 0.6931471805599453
# Cost after iteration 2395000: 0.6931471805599453
# Cost after iteration 2396000: 0.6931471805599453
# Cost after iteration 2397000: 0.6931471805599453
# Cost after iteration 2398000: 0.6931471805599453
# Cost after iteration 2399000: 0.6931471805599453
# Cost after iteration 2400000: 0.6931471805599453
# Cost after iteration 2401000: 0.6931471805599453
# Cost after iteration 2402000: 0.6931471805599453
# Cost after iteration 2403000: 0.6931471805599453
# Cost after iteration 2404000: 0.6931471805599453
# Cost after iteration 2405000: 0.6931471805599453
# Cost after iteration 2406000: 0.6931471805599453
# Cost after iteration 2407000: 0.6931471805599453
# Cost after iteration 2408000: 0.6931471805599453
# Cost after iteration 2409000: 0.6931471805599453
# Cost after iteration 2410000: 0.6931471805599453
# Cost after iteration 2411000: 0.6931471805599453
# Cost after iteration 2412000: 0.6931471805599453
# Cost after iteration 2413000: 0.6931471805599453
# Cost after iteration 2414000: 0.6931471805599453
# Cost after iteration 2415000: 0.6931471805599453
# Cost after iteration 2416000: 0.6931471805599453
# Cost after iteration 2417000: 0.6931471805599453
# Cost after iteration 2418000: 0.6931471805599453
# Cost after iteration 2419000: 0.6931471805599453
# Cost after iteration 2420000: 0.6931471805599453
# Cost after iteration 2421000: 0.6931471805599453
# Cost after iteration 2422000: 0.6931471805599453
# Cost after iteration 2423000: 0.6931471805599453
# Cost after iteration 2424000: 0.6931471805599453
# Cost after iteration 2425000: 0.6931471805599453
# Cost after iteration 2426000: 0.6931471805599453
# Cost after iteration 2427000: 0.6931471805599453
# Cost after iteration 2428000: 0.6931471805599453
# Cost after iteration 2429000: 0.6931471805599453
# Cost after iteration 2430000: 0.6931471805599453
# Cost after iteration 2431000: 0.6931471805599453
# Cost after iteration 2432000: 0.6931471805599453
# Cost after iteration 2433000: 0.6931471805599453
# Cost after iteration 2434000: 0.6931471805599453
# Cost after iteration 2435000: 0.6931471805599453
# Cost after iteration 2436000: 0.6931471805599453
# Cost after iteration 2437000: 0.6931471805599453
# Cost after iteration 2438000: 0.6931471805599453
# Cost after iteration 2439000: 0.6931471805599453
# Cost after iteration 2440000: 0.6931471805599453
# Cost after iteration 2441000: 0.6931471805599453
# Cost after iteration 2442000: 0.6931471805599453
# Cost after iteration 2443000: 0.6931471805599453
# Cost after iteration 2444000: 0.6931471805599453
# Cost after iteration 2445000: 0.6931471805599453
# Cost after iteration 2446000: 0.6931471805599453
# Cost after iteration 2447000: 0.6931471805599453
# Cost after iteration 2448000: 0.6931471805599453
# Cost after iteration 2449000: 0.6931471805599453
# Cost after iteration 2450000: 0.6931471805599453
# Cost after iteration 2451000: 0.6931471805599453
# Cost after iteration 2452000: 0.6931471805599453
# Cost after iteration 2453000: 0.6931471805599453
# Cost after iteration 2454000: 0.6931471805599453
# Cost after iteration 2455000: 0.6931471805599453
# Cost after iteration 2456000: 0.6931471805599453
# Cost after iteration 2457000: 0.6931471805599453
# Cost after iteration 2458000: 0.6931471805599453
# Cost after iteration 2459000: 0.6931471805599453
# Cost after iteration 2460000: 0.6931471805599453
# Cost after iteration 2461000: 0.6931471805599453
# Cost after iteration 2462000: 0.6931471805599453
# Cost after iteration 2463000: 0.6931471805599453
# Cost after iteration 2464000: 0.6931471805599453
# Cost after iteration 2465000: 0.6931471805599453
# Cost after iteration 2466000: 0.6931471805599453
# Cost after iteration 2467000: 0.6931471805599453
# Cost after iteration 2468000: 0.6931471805599453
# Cost after iteration 2469000: 0.6931471805599453
# Cost after iteration 2470000: 0.6931471805599453
# Cost after iteration 2471000: 0.6931471805599453
# Cost after iteration 2472000: 0.6931471805599453
# Cost after iteration 2473000: 0.6931471805599453
# Cost after iteration 2474000: 0.6931471805599453
# Cost after iteration 2475000: 0.6931471805599453
# Cost after iteration 2476000: 0.6931471805599453
# Cost after iteration 2477000: 0.6931471805599453
# Cost after iteration 2478000: 0.6931471805599453
# Cost after iteration 2479000: 0.6931471805599453
# Cost after iteration 2480000: 0.6931471805599453
# Cost after iteration 2481000: 0.6931471805599453
# Cost after iteration 2482000: 0.6931471805599453
# Cost after iteration 2483000: 0.6931471805599453
# Cost after iteration 2484000: 0.6931471805599453
# Cost after iteration 2485000: 0.6931471805599453
# Cost after iteration 2486000: 0.6931471805599453
# Cost after iteration 2487000: 0.6931471805599453
# Cost after iteration 2488000: 0.6931471805599453
# Cost after iteration 2489000: 0.6931471805599453
# Cost after iteration 2490000: 0.6931471805599453
# Cost after iteration 2491000: 0.6931471805599453
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 parameters = model(train_X, train_Y, initialization = "zeros")
#       2 print ("On the train set:")
#       3 predictions_train = predict(train_X, train_Y, parameters)
#
# Cell In[4], line 35, in model(X, Y, learning_rate, num_iterations, print_cost, initialization)
#      30 # Loop (gradient descent)
#      32 for i in range(num_iterations):
#      33
#      34     # Forward propagation: LINEAR -> RELU -> LINEAR -> RELU -> LINEAR -> SIGMOID.
# ---> 35     a3, cache = forward_propagation(X, parameters)
#      37     # Loss
#      38     cost = compute_loss(a3, Y)
#
# File ~/one_year_courses/mycoding_works/machine_learning/deep_learning Specialization/Improving Deep Neural network hyperparamaterizaration/week 1 lab/week 1 lab solutions/W1A1/init_utils.py:63, in forward_propagation(X, parameters)
#      61 # LINEAR -> RELU -> LINEAR -> RELU -> LINEAR -> SIGMOID
#      62 z1 = np.dot(W1, X) + b1
# ---> 63 a1 = relu(z1)
#      64 z2 = np.dot(W2, a1) + b2
#      65 a2 = relu(z2)
#
# File ~/one_year_courses/mycoding_works/machine_learning/deep_learning Specialization/Improving Deep Neural network hyperparamaterizaration/week 1 lab/week 1 lab solutions/W1A1/init_utils.py:20, in relu(x)
#      17     s = 1/(1+np.exp(-x))
#      18     return s
# ---> 20 def relu(x):
#      21     """
#      22     Compute the relu of x
#      23
#    (...)
#      28     s -- relu(x)
#      29     """
#      30     s = np.maximum(0,x)
#
# KeyboardInterrupt:

# %% [markdown]
# The performance is terrible, the cost doesn't decrease, and the algorithm performs no better than random guessing. Why? Take a look at the details of the predictions and the decision boundary:

# %%
print ("predictions_train = " + str(predictions_train))
print ("predictions_test = " + str(predictions_test))

# %%
plt.title("Model with Zeros initialization")
axes = plt.gca()
axes.set_xlim([-1.5,1.5])
axes.set_ylim([-1.5,1.5])
plot_decision_boundary(lambda x: predict_dec(parameters, x.T), train_X, train_Y)

# %% [markdown]
# For a comprehensive explanation of this, you can read *Paul Mielke*'s post, [Symmetry Breaking versus Zero Initialization](https://community.deeplearning.ai/t/symmetry-breaking-versus-zero-initialization/16061).
#
# A simple explanation is provided below:
#
# __Note__: For sake of simplicity calculations below are done using only one example at a time.
#
# Since the weights and biases are zero, multiplying by the weights creates the zero vector which gives 0 when the activation function is ReLU. As `z = 0`
#
# $$a = ReLU(z) = max(0, z) = 0$$
#
# At the classification layer, where the activation function is sigmoid you then get (for either input):
#
# $$\sigma(z) = \frac{1}{ 1 + e^{-(z)}} = \frac{1}{2} = y_{pred}$$
#
# As for every example you are getting a 0.5 chance of it being true our cost function becomes helpless in adjusting the weights.
#
# Your loss function:
# $$ \mathcal{L}(a, y) =  - y  \ln(y_{pred}) - (1-y)  \ln(1-y_{pred})$$
#
# For `y=1`, `y_pred=0.5` it becomes:
#
# $$ \mathcal{L}(0, 1) =  - (1)  \ln(\frac{1}{2}) = 0.6931471805599453$$
#
# For `y=0`, `y_pred=0.5` it becomes:
#
# $$ \mathcal{L}(0, 0) =  - (1)  \ln(\frac{1}{2}) = 0.6931471805599453$$
#
# As you can see with the prediction being 0.5 whether the actual (`y`) value is 1 or 0 you get the same loss value for both, so none of the weights get adjusted and you are stuck with the same old value of the weights.
#
# This is why you can see that the model is predicting 0 for every example! No wonder it's doing so badly.
#
# In general, initializing all the weights to zero results in the network failing to break symmetry. This means that every neuron in each layer will learn the same thing, so you might as well be training a neural network with $n^{[l]}=1$ for every layer. This way, the network is no more powerful than a linear classifier like logistic regression.

# %% [markdown]
# <font color='blue'>
#
# **What you should remember**:
# - The weights $W^{[l]}$ should be initialized randomly to break symmetry.
# - However, it's okay to initialize the biases $b^{[l]}$ to zeros. Symmetry is still broken so long as $W^{[l]}$ is initialized randomly.

# %% [markdown]
# <a name='5'></a>
# ## 5 - Random Initialization
#
# To break symmetry, initialize the weights randomly. Following random initialization, each neuron can then proceed to learn a different function of its inputs. In this exercise, you'll see what happens when the weights are initialized randomly, but to very large values.
#
# <a name='ex-2'></a>
# ### Exercise 2 - initialize_parameters_random
#
# Implement the following function to initialize your weights to large random values (scaled by \*10) and your biases to zeros. Use `np.random.randn(..,..) * 10` for weights and `np.zeros((.., ..))` for biases. You're using a fixed `np.random.seed(..)` to make sure your "random" weights  match ours, so don't worry if running your code several times always gives you the same initial values for the parameters.

# %%
# GRADED FUNCTION: initialize_parameters_random

def initialize_parameters_random(layers_dims):
    """
    Arguments:
    layer_dims -- python array (list) containing the size of each layer.
    
    Returns:
    parameters -- python dictionary containing your parameters "W1", "b1", ..., "WL", "bL":
                    W1 -- weight matrix of shape (layers_dims[1], layers_dims[0])
                    b1 -- bias vector of shape (layers_dims[1], 1)
                    ...
                    WL -- weight matrix of shape (layers_dims[L], layers_dims[L-1])
                    bL -- bias vector of shape (layers_dims[L], 1)
    """
    
    
    
    np.random.seed(3)               # This seed makes sure your "random" numbers will be the as ours
    parameters = {}
    L = len(layers_dims)            # integer representing the number of layers
    
    for l in range(1, L):
        #(≈ 2 lines of code)
        # parameters['W' + str(l)] = 
        # parameters['b' + str(l)] =
        # YOUR CODE STARTS HERE
        parameters["W"+str(l)]=np.random.randn(layers_dims[l],layers_dims[l-1])*0.001
        parameters["b"+str(l)]=np.zeros((layers_dims[l],1))
        
        
        # YOUR CODE ENDS HERE

    return parameters

# %%
parameters = initialize_parameters_random([3, 2, 1])
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
initialize_parameters_random_test(initialize_parameters_random)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 parameters = initialize_parameters_random([3, 2, 1])
#       2 print("W1 = " + str(parameters["W1"]))
#       3 print("b1 = " + str(parameters["b1"]))
#
# NameError: name 'initialize_parameters_random' is not defined

# %% [markdown]
# Run the following code to train your model on 15,000 iterations using random initialization.

# %%
parameters = model(train_X, train_Y, initialization = "random")
print ("On the train set:")
predictions_train = predict(train_X, train_Y, parameters)
print ("On the test set:")
predictions_test = predict(test_X, test_Y, parameters)

# %% [markdown]
# If you see "inf" as the cost after the iteration 0, this is because of numerical roundoff. A more numerically sophisticated implementation would fix this, but for the purposes of this notebook, it isn't really worth worrying about.
#
# In any case, you've now broken the symmetry, and this gives noticeably better accuracy than before. The model is no longer outputting all 0s. Progress!

# %%
print (predictions_train)
print (predictions_test)

# %%
plt.title("Model with large random initialization")
axes = plt.gca()
axes.set_xlim([-1.5,1.5])
axes.set_ylim([-1.5,1.5])
plot_decision_boundary(lambda x: predict_dec(parameters, x.T), train_X, train_Y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 5
#       3 axes.set_xlim([-1.5,1.5])
#       4 axes.set_ylim([-1.5,1.5])
# ----> 5 plot_decision_boundary(lambda x: predict_dec(parameters, x.T), train_X, train_Y)
#
# File ~/one_year_courses/mycoding_works/machine_learning/deep_learning Specialization/Improving Deep Neural network hyperparamaterizaration/week 1 lab/week 1 lab solutions/W1A1/init_utils.py:211, in plot_decision_boundary(model, X, y)
#     209 xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
#     210 # Predict the function value for the whole grid
# --> 211 Z = model(np.c_[xx.ravel(), yy.ravel()])
#     212 Z = Z.reshape(xx.shape)
#     213 # Plot the contour and training examples
#
# Cell In[10], line 5, in <lambda>(x)
#       3 axes.set_xlim([-1.5,1.5])
#       4 axes.set_ylim([-1.5,1.5])
# ----> 5 plot_decision_boundary(lambda x: predict_dec(parameters, x.T), train_X, train_Y)
#
# File ~/one_year_courses/mycoding_works/machine_learning/deep_learning Specialization/Improving Deep Neural network hyperparamaterizaration/week 1 lab/week 1 lab solutions/W1A1/init_utils.py:233, in predict_dec(parameters, X)
#     221 """
#     222 Used for plotting decision boundary.
#     223
#    (...)
#     229 predictions -- vector of predictions of our model (red: 0 / blue: 1)
#     230 """
#     232 # Predict using forward propagation and a classification threshold of 0.5
# --> 233 a3, cache = forward_propagation(X, parameters)
#     234 predictions = (a3>0.5)
#     235 return predictions
#
# File ~/one_year_courses/mycoding_works/machine_learning/deep_learning Specialization/Improving Deep Neural network hyperparamaterizaration/week 1 lab/week 1 lab solutions/W1A1/init_utils.py:58, in forward_propagation(X, parameters)
#      56 W2 = parameters["W2"]
#      57 b2 = parameters["b2"]
# ---> 58 W3 = parameters["W3"]
#      59 b3 = parameters["b3"]
#      61 # LINEAR -> RELU -> LINEAR -> RELU -> LINEAR -> SIGMOID
#
# KeyError: 'W3'

# %% [markdown]
# **Observations**:
# - The cost starts very high. This is because with large random-valued weights, the last activation (sigmoid) outputs results that are very close to 0 or 1 for some examples, and when it gets that example wrong it incurs a very high loss for that example. Indeed, when $\log(a^{[3]}) = \log(0)$, the loss goes to infinity.
# - Poor initialization can lead to vanishing/exploding gradients, which also slows down the optimization algorithm.
# - If you train this network longer you will see better results, but initializing with overly large random numbers slows down the optimization.
#
# <font color='blue'>
#
# **In summary**:
# - Initializing weights to very large random values doesn't work well.
# - Initializing with small random values should do better. The important question is, how small should be these random values be? Let's find out up next!
#
# <font color='black'>
#
# **Optional Read:**
#
#
# The main difference between Gaussian variable (`numpy.random.randn()`) and uniform random variable is the distribution of the generated random numbers:
#
# - numpy.random.rand() produces numbers in a [uniform distribution](https://raw.githubusercontent.com/jahnog/deeplearning-notes/master/Course2/images/rand.jpg).
# - and numpy.random.randn() produces numbers in a [normal distribution](https://raw.githubusercontent.com/jahnog/deeplearning-notes/master/Course2/images/randn.jpg).
#
# When used for weight initialization, randn() helps most the weights to Avoid being close to the extremes, allocating most of them in the center of the range.
#
# An intuitive way to see it is, for example, if you take the [sigmoid() activation function](https://raw.githubusercontent.com/jahnog/deeplearning-notes/master/Course2/images/sigmoid.jpg).
#
# You’ll remember that the slope near 0 or near 1 is extremely small, so the weights near those extremes will converge much more slowly to the solution, and having most of them near the center will speed the convergence.

# %% [markdown]
# <a name='6'></a>
# ## 6 - He Initialization
#
# Finally, try "He Initialization"; this is named for the first author of He et al., 2015. (If you have heard of "Xavier initialization", this is similar except Xavier initialization uses a scaling factor for the weights $W^{[l]}$ of `sqrt(1./layers_dims[l-1])` where He initialization would use `sqrt(2./layers_dims[l-1])`.)
#
# <a name='ex-3'></a>
# ### Exercise 3 - initialize_parameters_he
#
# Implement the following function to initialize your parameters with He initialization. This function is similar to the previous `initialize_parameters_random(...)`. The only difference is that instead of multiplying `np.random.randn(..,..)` by 10, you will multiply it by $\sqrt{\frac{2}{\text{dimension of the previous layer}}}$, which is what He initialization recommends for layers with a ReLU activation.

# %%
# GRADED FUNCTION: initialize_parameters_he

def initialize_parameters_he(layers_dims):
    """
    Arguments:
    layer_dims -- python array (list) containing the size of each layer.
    
    Returns:
    parameters -- python dictionary containing your parameters "W1", "b1", ..., "WL", "bL":
                    W1 -- weight matrix of shape (layers_dims[1], layers_dims[0])
                    b1 -- bias vector of shape (layers_dims[1], 1)
                    ...
                    WL -- weight matrix of shape (layers_dims[L], layers_dims[L-1])
                    bL -- bias vector of shape (layers_dims[L], 1)
    """
    
    np.random.seed(3)
    parameters = {}
    L = len(layers_dims) - 1 # integer representing the number of layers
     
    for l in range(1, L + 1):
        #(≈ 2 lines of code)
        # parameters['W' + str(l)] = 
        # parameters['b' + str(l)] =
        # YOUR CODE STARTS HERE
        parameters["W"+str(l)]=np.random.randn(layers_dims[l],layers_dims[l-1])*np.sqrt(2/layers_dims[l-1])
        parameters["b"+str(l)]=np.zeros((layers_dims[l],1))
        
        
        # YOUR CODE ENDS HERE
        
    return parameters

# %%
parameters = initialize_parameters_he([2, 4, 1])
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))

initialize_parameters_he_test(initialize_parameters_he)
# parameters

# %% [markdown]
# **Expected output**
#
# ```
# W1 = [[ 1.78862847  0.43650985]
#  [ 0.09649747 -1.8634927 ]
#  [-0.2773882  -0.35475898]
#  [-0.08274148 -0.62700068]]
# b1 = [[0.] [0.] [0.] [0.]]
# W2 = [[-0.03098412 -0.33744411 -0.92904268  0.62552248]]
# b2 = [[0.]]
# ```

# %% [markdown]
# Run the following code to train your model on 15,000 iterations using He initialization.

# %%
parameters = model(train_X, train_Y, initialization = "he")
print ("On the train set:")
predictions_train = predict(train_X, train_Y, parameters)
print ("On the test set:")
predictions_test = predict(test_X, test_Y, parameters)

# %%
plt.title("Model with He initialization")
axes = plt.gca()
axes.set_xlim([-1.5,1.5])
axes.set_ylim([-1.5,1.5])
plot_decision_boundary(lambda x: predict_dec(parameters, x.T), train_X, train_Y)

# %% [markdown]
# **Observations**:
# - The model with He initialization separates the blue and the red dots very well in a small number of iterations.

# %% [markdown]
# <a name='7'></a>
# ## 7 - Conclusions

# %% [markdown]
# You've tried three different types of initializations. For the same number of iterations and same hyperparameters, the comparison is:
#
# <table>
#     <tr>
#         <td>
#             <b>Model</b>
#         </td>
#         <td>
#             <b>Train accuracy</b>
#         </td>
#         <td>
#             <b>Problem/Comment</b>
#         </td>
#     </tr>
#         <td>
#         3-layer NN with zeros initialization
#         </td>
#         <td>
#         50%
#         </td>
#         <td>
#         fails to break symmetry
#         </td>
#     <tr>
#         <td>
#         3-layer NN with large random initialization
#         </td>
#         <td>
#         83%
#         </td>
#         <td>
#         too large weights
#         </td>
#     </tr>
#     <tr>
#         <td>
#         3-layer NN with He initialization
#         </td>
#         <td>
#         99%
#         </td>
#         <td>
#         recommended method
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Congratulations**! You've completed this notebook on Initialization.
#
# Here's a quick recap of the main takeaways:
#
# <font color='blue'>
#
# - Different initializations lead to very different results
# - Random initialization is used to break symmetry and make sure different hidden units can learn different things
# - Resist initializing to values that are too large!
# - He initialization works well for networks with ReLU activations
